# %%
from torch import randint
from torchmetrics.classification import MulticlassConfusionMatrix
import torch

# %%
metric = MulticlassConfusionMatrix(num_classes=8)

# Load the state dictionary from the file
state_dict = torch.load("confusion_matrix_val.pth")

# Load the state dictionary into the metric
metric.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
fig_, ax_ = metric.plot()
# Out:
# /home/diego/miniconda3/envs/fma/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of metric MulticlassConfusionMatrix was called before the ``update`` method which may lead to errors, as metric states have not yet been updated.
#   warnings.warn(*args, **kwargs)  # noqa: B028
