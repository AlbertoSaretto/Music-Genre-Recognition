# %%
# %matplotlib inline

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display

import utils

plt.rcParams['figure.figsize'] = (17, 5)

# %%
pip install google.colab
# Out:
# ...
#   Using cached google_colab-1.0.0-py2.py3-none-any.whl
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached ipython-5.5.0-py3-none-any.whl (758 kB)
# ...
#   Using cached ipykernel-4.6.1-py3-none-any.whl (104 kB)
# ...
#   Using cached pandas-0.24.2.tar.gz (11.8 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# ...
#   Using cached jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#   Using cached jupyter_client-8.4.0-py3-none-any.whl (103 kB)
#   Using cached jupyter_client-8.3.1-py3-none-any.whl (104 kB)
#   Using cached jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#   Using cached jupyter_client-8.2.0-py3-none-any.whl (103 kB)
#   Using cached jupyter_client-8.1.0-py3-none-any.whl (102 kB)
#   Using cached jupyter_client-8.0.3-py3-none-any.whl (102 kB)
#   Using cached jupyter_client-8.0.2-py3-none-any.whl (103 kB)
#   Using cached jupyter_client-8.0.1-py3-none-any.whl (103 kB)
# ...

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/gdrive')

# Directory where mp3 files are stored in Google Drive.
AUDIO_DIR = '/content/gdrive/MyDrive/path/to/your/mp3/files'

# Load metadata and features.
tracks = utils.load(os.path.join(AUDIO_DIR, 'data/fma_metadata/tracks.csv'))
genres = utils.load(os.path.join(AUDIO_DIR, 'data/fma_metadata/genres.csv'))
features = utils.load(os.path.join(AUDIO_DIR, 'data/fma_metadata/features.csv'))
echonest = utils.load(os.path.join(AUDIO_DIR, 'data/fma_metadata/echonest.csv'))

np.testing.assert_array_equal(features.index, tracks.index)
assert echonest.index.isin(tracks.index).all()

tracks.shape, genres.shape, features.shape, echonest.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from google.colab import drive
#       2 import os
#       4 # Mount Google Drive
#
# ModuleNotFoundError: No module named 'google.colab'
